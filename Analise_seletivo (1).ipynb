# %% [markdown]
# ## Importando bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import webbrowser

# %%
dados = pd.read_excel("seletivo_centrismos.xlsx")

# %%
dados.head()
# Out:
#                        Nome completo     Telefone  \
# 0   Daniel Henrique Teodoro de Souza  11983960762
# 1    Pedro Augusto de Jesus da Silva  21985319506
# 2  Ricardo Martinez Siqueira Junior   11941967303
# 3  André Ricardo Zimmermann da Silva  14998222161
# 4             Eldio Luiz Cortez Neto  84998271056
#
#                         E-mail    Twitter       Instagram  \
# 0        dhenrique47@gmail.com      dhts0           dhts2
# 1         pedroajs93@gmail.com  pedroajs1  pedroaugustojs
# 2        ribas1322@outlook.com        NaN             NaN
# 3  andre_zimmermen@hotmail.com        NaN             NaN
# 4          cortezneto@live.com   safstand    elcortezneto
#
#                                             Formação Estado  \
# 0  Bacharelado em Letras (Tradução - Inglês, 2015...     SP
# 1               Graduação em Relações Internacionais     RJ
# 2                     Relações Internacionais na FMU     SP
# 3                              Graduação em História     SP
# ...

# %% [markdown]
# ## Informações pessoais e contato

# %%
nomes= list(dados['Nome completo'].str.title())  # padroniza os nomes 
emails = list(dados['E-mail'])
idade = list(dados['Idade'])
estado = list(dados['Estado'])
telefone = list(dados['Telefone'])

dados['Nome completo']= nomes

# %% [markdown]
# ## Idiomas

# %%
#-----idiomas-------
ing = dados['idiomas [Inglês]'].value_counts()
esp=dados['idiomas [Espanhol]'].value_counts()
ale=dados['idiomas [Alemão]'].value_counts()
fra=dados['idiomas [Francês]'].value_counts()
ita=dados['idiomas [Italiano]'].value_counts()
#-------end------------

# %%
print(ing)
print('\n')
print(esp)
print('\n')
print(fra)
print('\n')
print(ale)
# Out:
# Avançado         12
# Intermediário    11
# Fluente          11
# Nativo            1
# Básico            1
# Name: idiomas [Inglês], dtype: int64
#
#
# Intermediário    9
# Básico           8
# Avançado         4
# Fluente          1
# Name: idiomas [Espanhol], dtype: int64
#
#
# Básico           6
# Intermediário    1
# Avançado         1
# Name: idiomas [Francês], dtype: int64
#
#
# Básico      5
# Avançado    1
# Name: idiomas [Alemão], dtype: int64

# %%
plt.figure(figsize=(15, 5))

plt.subplot(151)
plt.pie(ing.values,labels = ing.index,autopct= '%1.1f%%')
plt.title('Nivel de ingles')

plt.subplot(152)
plt.pie(esp.values,labels = esp.index,autopct= '%1.1f%%')
plt.title('Nivel de espanhol')

plt.subplot(153)
plt.pie(ale.values,labels = ale.index,autopct= '%1.1f%%')
plt.title('Nivel de alemao')

plt.subplot(154)
plt.pie(ita.values,labels = ita.index,autopct= '%1.1f%%')
plt.title('Nivel de italiano')

plt.subplot(155)
plt.pie(fra.values,labels = fra.index,autopct= '%1.1f%%')
plt.title('Nivel de frances')

plt.suptitle('IDIOMAS')
plt.show()

# %% [markdown]
# ## Distribuição por estados

# %%
plt.bar(dados.Estado.value_counts().index,dados.Estado.value_counts().values)
plt.title('Distribuição por estados')
# Out:
# Text(0.5, 1.0, 'Distribuição por estados')

# %% [markdown]
# ## analise de setores

# %%
#-----dataframes de cada setor------
# seleciona aepnas as colunas com informações pertimentes a cada setor

grafico = dados[dados['Setor Gráfico']=='Sim']
grafico = grafico.drop(['Setor Acadêmico', 'Assuntos', 'Setor Edição', 'Setor Edição (função)',
       'Softwares de edição', 'Setor Técnico', 'Setor Técnico (função)',
       'Tecnologias: [Excel]', 'Tecnologias: [Pacote Office]',
       'Tecnologias: [GSuite]', 'Tecnologias: [R]', 'Tecnologias: [Python]',
       'Tecnologias: [PowerBI]', 'Tecnologias: [Shell script]',
       'Tecnologias: [PHP]', 'Tecnologias: [WordPress]',
       'Outra linguagem de programação?'],axis=1)

editor = dados[dados['Setor Edição']=='Sim']
editor = editor.drop(['Setor Gráfico', 'experiência ferramentas', 'portfolio',
       'Setor Acadêmico', 'Assuntos', 'Setor Técnico', 'Setor Técnico (função)',
       'Tecnologias: [Excel]', 'Tecnologias: [Pacote Office]',
       'Tecnologias: [GSuite]', 'Tecnologias: [R]', 'Tecnologias: [Python]',
       'Tecnologias: [PowerBI]', 'Tecnologias: [Shell script]',
       'Tecnologias: [PHP]', 'Tecnologias: [WordPress]',
       'Outra linguagem de programação?'],axis=1)


academico = dados[dados['Setor Acadêmico']=='Sim']
academico = academico.drop(['Setor Gráfico', 'experiência ferramentas', 'portfolio',
       'Setor Edição', 'Setor Edição (função)',
       'Softwares de edição', 'Setor Técnico', 'Setor Técnico (função)',
       'Tecnologias: [Excel]', 'Tecnologias: [Pacote Office]',
       'Tecnologias: [GSuite]', 'Tecnologias: [R]', 'Tecnologias: [Python]',
       'Tecnologias: [PowerBI]', 'Tecnologias: [Shell script]',
       'Tecnologias: [PHP]', 'Tecnologias: [WordPress]',
       'Outra linguagem de programação?'],axis=1)

tecnico = dados[dados['Setor Técnico']=='Sim']
tecnico = tecnico.drop(['Setor Gráfico', 'experiência ferramentas', 'portfolio',
       'Setor Acadêmico', 'Assuntos', 'Setor Edição', 'Setor Edição (função)',
       'Softwares de edição'],axis=1)

#------end-------

# %%
grafico
# Out:
#                              Nome completo     Telefone  \
# 8               Henrique Florencio De Lima  31995582093
# 10           Thiago Francisco Dutra Galvao  81998308007
# 12                             Rafael Rosa  21976076752
# 15                     Matheus H P Corradi  31993328034
# 18  João Guilherme Nantes Pereira Da Silva  21973580201
# 22                  Artur Pereira Da Silva  89999023379
# 26                Fernando Rebés Velo Neto  55999207434
# 32                  Felipe Soderini Erlich  11965730430
# 33  Estevao Raffaine Vilas Boas De Freitas  11986428118
#
#                          E-mail                         Twitter  \
# 8        henriquelm50@gmail.com                    henriquelm50
# 10    thiago.dutra008@gmail.com                         Otdutra
# 12   rafaasforadarosa@gmail.com                     rafarosa971
# 15   matheuscorradi20@gmail.com                       CorradiBR
# 18         jgnantes99@gmail.com                             NaN
# ...

# %%
tecnico
# Out:
#                              Nome completo     Telefone  \
# 1          Pedro Augusto De Jesus Da Silva  21985319506
# 4                   Eldio Luiz Cortez Neto  84998271056
# 11                  Phelipe Oliveira Jesus  11964792391
# 13        Fábio Mcgougen Nogueira Correia   17988228819
# 17                      Felipe Ito Anuatti  16993078433
# 19                         Ranieri Althoff  46760298255
# 20              Vinicius Nascimento Aguiar  19999361919
# 22                  Artur Pereira Da Silva  89999023379
# 28                   Gendson Teles Moreira  38992571105
# 33  Estevao Raffaine Vilas Boas De Freitas  11986428118
# 34                 Mateus Santos Rodrigues  11959578440
#
#                               E-mail         Twitter        Instagram  \
# 1               pedroajs93@gmail.com       pedroajs1   pedroaugustojs
# 4                cortezneto@live.com        safstand     elcortezneto
# 11   phelipe_oliveira_97@hotmail.com  phelipe_oliver              NaN
# ...

# %%
academico
# Out:
#                              Nome completo     Telefone  \
# 0         Daniel Henrique Teodoro De Souza  11983960762
# 2        Ricardo Martinez Siqueira Junior   11941967303
# 3        André Ricardo Zimmermann Da Silva  14998222161
# 4                   Eldio Luiz Cortez Neto  84998271056
# 5                    Petrus Coelho Pereira  44988517734
# 6                     Gian Luca Nagy Elian  11975142728
# 7                   Gustavo Cunha Graziani  62999722886
# 8               Henrique Florencio De Lima  31995582093
# 9      Bruno César Linhares Da Costa Silva  84999873397
# 10           Thiago Francisco Dutra Galvao  81998308007
# 11                  Phelipe Oliveira Jesus  11964792391
# 12                             Rafael Rosa  21976076752
# 14       Luiz Gustavo Cavalcanti De Araújo  24999872000
# 15                     Matheus H P Corradi  31993328034
# 16                     Gilson Luiz Crispim  34988696673
# 17                      Felipe Ito Anuatti  16993078433
# ...

# %%
editor
# Out:
#                              Nome completo     Telefone  \
# 10           Thiago Francisco Dutra Galvao  81998308007
# 18  João Guilherme Nantes Pereira Da Silva  21973580201
# 26                Fernando Rebés Velo Neto  55999207434
# 30               Israel Martinez Rodrigues   1143128826
#
#                          E-mail                         Twitter  \
# 10    thiago.dutra008@gmail.com                         Otdutra
# 18         jgnantes99@gmail.com                             NaN
# 26  fernandorebesvelo@gmail.com  fernandovelo e centroliberalBR
# 30        israelhp7p2@gmail.com                      IsraelM98_
#
#               Instagram                                           Formação  \
# 10              Otdutra                     Graduando em história - UNICAP
# 18                  NaN                  Design de Mídia Digital – PUC-Rio
# 26         fernandovelo                                    DIREITO - PUCRS
# ...

# %% [markdown]
# ## SETOR ACADEMICO

# %%
#-----Setor academico por assuntos------



for i in academico['Assuntos'].index:
    academico["Assuntos"][i]=academico["Assuntos"][i].split(',')

#------end ----------
# Out:
# <ipython-input-48-d789a1531673>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   academico["Assuntos"][i]=academico["Assuntos"][i].split(',')

# %%
# listas para armazenar o indices dos inscritos por areas de interesse 
lista_index_econ = []
lista_index_dir = []
lista_index_pol = []
lista_index_fil = []
lista_index_polex = []
lista_index_ecol = []
lista_index_hum = []
lista_index_geo = []

# preenhimento das listas

for i in academico['Assuntos'].index:
    for j in range(len(academico['Assuntos'][i])):
        
        # if academico['Assuntos'][i][j][0] == ' ':
        #     academico['Assuntos'][i][j] = academico['Assuntos'][i][j].replace(academico['Assuntos'][i][j][0],'')
        
        if academico['Assuntos'][i][j] == 'Economia':
            lista_index_econ.append(i)
        if academico['Assuntos'][i][j] == 'Política' :
            lista_index_pol.append(i)
        if academico['Assuntos'][i][j] == 'Direito':
            lista_index_dir.append(i)
        if academico['Assuntos'][i][j] == 'Política externa':
            lista_index_polex.append(i)
        if academico['Assuntos'][i][j] == 'Filosofia e filosofia política':
            lista_index_fil.append(i)
        if academico['Assuntos'][i][j] == 'Ecologia':
            lista_index_ecol.append(i)
        if academico['Assuntos'][i][j] == 'Ciências sociais e humanidades':
            lista_index_hum.append(i)
        if academico['Assuntos'][i][j] == 'Geografia':
            lista_index_geo.append(i)

# %% [markdown]
# ## Visualizar o setor academico por area de interesse

# %%
academico.loc[lista_index_dir,:]  # DIREITO
# Out:
#                         Nome completo     Telefone  \
# 0    Daniel Henrique Teodoro De Souza  11983960762
# 12                        Rafael Rosa  21976076752
# 14  Luiz Gustavo Cavalcanti De Araújo  24999872000
# 26           Fernando Rebés Velo Neto  55999207434
#
#                          E-mail                         Twitter  \
# 0         dhenrique47@gmail.com                           dhts0
# 12   rafaasforadarosa@gmail.com                     rafarosa971
# 14  luizgustavo_cda@hotmail.com                  luizgustavocav
# 26  fernandorebesvelo@gmail.com  fernandovelo e centroliberalBR
#
#           Instagram                                           Formação Estado  \
# 0             dhts2  Bacharelado em Letras (Tradução - Inglês, 2015...     SP
# 12       rafarosa97                Graduando em economia pelo IBMEC-RJ     RJ
# 14  luiz.gustavoadv  Direito pela UFF, Mestrando no programa de Dir...     RJ
# ...

# %%
academico.loc[lista_index_econ,:]  # Economia
# Out:
#                           Nome completo     Telefone  \
# 2     Ricardo Martinez Siqueira Junior   11941967303
# 4                Eldio Luiz Cortez Neto  84998271056
# 5                 Petrus Coelho Pereira  44988517734
# 6                  Gian Luca Nagy Elian  11975142728
# 7                Gustavo Cunha Graziani  62999722886
# 8            Henrique Florencio De Lima  31995582093
# 9   Bruno César Linhares Da Costa Silva  84999873397
# 11               Phelipe Oliveira Jesus  11964792391
# 12                          Rafael Rosa  21976076752
# 14    Luiz Gustavo Cavalcanti De Araújo  24999872000
# 15                  Matheus H P Corradi  31993328034
# 17                   Felipe Ito Anuatti  16993078433
# 22               Artur Pereira Da Silva  89999023379
# 27    Luiz Mario Andrade Gomes Da Silva  61981140027
# 34              Mateus Santos Rodrigues  11959578440
#
#                              E-mail         Twitter         Instagram  \
# ...

# %%
academico.loc[lista_index_pol,:]  # Politica
# Out:
#                              Nome completo     Telefone  \
# 2        Ricardo Martinez Siqueira Junior   11941967303
# 3        André Ricardo Zimmermann Da Silva  14998222161
# 4                   Eldio Luiz Cortez Neto  84998271056
# 6                     Gian Luca Nagy Elian  11975142728
# 7                   Gustavo Cunha Graziani  62999722886
# 8               Henrique Florencio De Lima  31995582093
# 9      Bruno César Linhares Da Costa Silva  84999873397
# 10           Thiago Francisco Dutra Galvao  81998308007
# 11                  Phelipe Oliveira Jesus  11964792391
# 14       Luiz Gustavo Cavalcanti De Araújo  24999872000
# 16                     Gilson Luiz Crispim  34988696673
# 17                      Felipe Ito Anuatti  16993078433
# 22                  Artur Pereira Da Silva  89999023379
# 23      Carlos José Dias Dos Santos Júnior  81999553636
# 26                Fernando Rebés Velo Neto  55999207434
# 27       Luiz Mario Andrade Gomes Da Silva  61981140027
# ...

# %%
academico.loc[lista_index_polex,:]  # Politica externa
# Out:
#                          Nome completo     Telefone  \
# 2    Ricardo Martinez Siqueira Junior   11941967303
# 6                 Gian Luca Nagy Elian  11975142728
# 7               Gustavo Cunha Graziani  62999722886
# 10       Thiago Francisco Dutra Galvao  81998308007
# 21         Leandro Madureira Magalhães  21965641713
# 22              Artur Pereira Da Silva  89999023379
# 23  Carlos José Dias Dos Santos Júnior  81999553636
# 24  Carlos Almir Barbosa Lima Oliveira  74991038774
# 26            Fernando Rebés Velo Neto  55999207434
# 29          Pedro Lucas Morais Pereira  31971237115
#
#                           E-mail                         Twitter  \
# 2          ribas1322@outlook.com                             NaN
# 6        Gianlucanagy2@gmail.com                    Nagyarorszag
# 7     gustavograziani1@gmail.com                     GrazianiGus
# 10     thiago.dutra008@gmail.com                         Otdutra
# ...

# %%
academico.loc[lista_index_fil,:]  # Filosofia
# Out:
#                              Nome completo     Telefone  \
# 3        André Ricardo Zimmermann Da Silva  14998222161
# 4                   Eldio Luiz Cortez Neto  84998271056
# 7                   Gustavo Cunha Graziani  62999722886
# 8               Henrique Florencio De Lima  31995582093
# 10           Thiago Francisco Dutra Galvao  81998308007
# 14       Luiz Gustavo Cavalcanti De Araújo  24999872000
# 16                     Gilson Luiz Crispim  34988696673
# 17                      Felipe Ito Anuatti  16993078433
# 18  João Guilherme Nantes Pereira Da Silva  21973580201
# 23      Carlos José Dias Dos Santos Júnior  81999553636
# 24      Carlos Almir Barbosa Lima Oliveira  74991038774
# 25         Marcus Vinicius Oliveira Santos  35998671270
# 26                Fernando Rebés Velo Neto  55999207434
# 27       Luiz Mario Andrade Gomes Da Silva  61981140027
# 29              Pedro Lucas Morais Pereira  31971237115
# 31            Jardel Costa Silva De Araújo  82988096882
# ...

# %%
academico.loc[lista_index_hum,:]  # Ciecnia sociais
# Out:
#                              Nome completo     Telefone  \
# 3        André Ricardo Zimmermann Da Silva  14998222161
# 10           Thiago Francisco Dutra Galvao  81998308007
# 14       Luiz Gustavo Cavalcanti De Araújo  24999872000
# 16                     Gilson Luiz Crispim  34988696673
# 17                      Felipe Ito Anuatti  16993078433
# 21             Leandro Madureira Magalhães  21965641713
# 22                  Artur Pereira Da Silva  89999023379
# 23      Carlos José Dias Dos Santos Júnior  81999553636
# 24      Carlos Almir Barbosa Lima Oliveira  74991038774
# 26                Fernando Rebés Velo Neto  55999207434
# 27       Luiz Mario Andrade Gomes Da Silva  61981140027
# 28                   Gendson Teles Moreira  38992571105
# 29              Pedro Lucas Morais Pereira  31971237115
# 31            Jardel Costa Silva De Araújo  82988096882
# 33  Estevao Raffaine Vilas Boas De Freitas  11986428118
# 35                         Leonardo Santos  11958275407
#
# ...

# %%
academico.loc[lista_index_ecol,:]  # Ecologia
# Out:
#                 Nome completo     Telefone                   E-mail  \
# 4      Eldio Luiz Cortez Neto  84998271056      cortezneto@live.com
# 6        Gian Luca Nagy Elian  11975142728  Gianlucanagy2@gmail.com
# 8  Henrique Florencio De Lima  31995582093   henriquelm50@gmail.com
#
#         Twitter     Instagram                                    Formação  \
# 4      safstand  elcortezneto          Estou cursando Engenharia Elétrica
# 6  Nagyarorszag           NaN                 Cursando Geografia, no IFSP
# 8  henriquelm50           NaN  Cursando Análises clínicas, COLTEC - UFMG.
#
#   Estado Reside fora do Brasil? País   Idade idiomas [Inglês]  \
# 4     RN                          NaN     24    Intermediário
# 6     SP                          NaN     21         Avançado
# 8     MG                          NaN     18    Intermediário
#
#   idiomas [Espanhol] idiomas [Francês] idiomas [Italiano] idiomas [Alemão]  \
# ...

# %%
academico.loc[lista_index_geo,:]  # Geografia
# Out:
#                          Nome completo     Telefone  \
# 6                 Gian Luca Nagy Elian  11975142728
# 10       Thiago Francisco Dutra Galvao  81998308007
# 21         Leandro Madureira Magalhães  21965641713
# 22              Artur Pereira Da Silva  89999023379
# 24  Carlos Almir Barbosa Lima Oliveira  74991038774
#
#                        E-mail        Twitter      Instagram  \
# 6     Gianlucanagy2@gmail.com   Nagyarorszag            NaN
# 10  thiago.dutra008@gmail.com        Otdutra        Otdutra
# 21    whosmadureira@gmail.com  whosmadureira  whosmadureira
# 22        arturapsq@gmail.com      Arturbr97      arturps97
# 24     bcarlosalmir@gmail.com            NaN            NaN
#
#                                              Formação Estado  \
# 6                         Cursando Geografia, no IFSP     SP
# 10                     Graduando em história - UNICAP     PE
# 21  Graduação em Biblioteconomia e Gestão de Unida...     RJ
# ...

# %% [markdown]
# ## SETOR TECNICO

# %%
#--------Setor Tecnico--------

for i in tecnico['Setor Técnico (função)'].index:
    tecnico['Setor Técnico (função)'][i]=tecnico['Setor Técnico (função)'][i].split(',')
    
# lista para armazenar os indices dos inscrtiso de acordo com a função
lista_index_prog = []
lista_index_dados = []

for i in tecnico['Setor Técnico (função)'].index:
    for j in range(len(tecnico['Setor Técnico (função)'][i])):
        
        # if academico['Assuntos'][i][j][0] == ' ':
        #     academico['Assuntos'][i][j] = academico['Assuntos'][i][j].replace(academico['Assuntos'][i][j][0],'')
        
        if tecnico['Setor Técnico (função)'][i][j] == 'Programação':
            lista_index_prog.append(i)
        if tecnico['Setor Técnico (função)'][i][j] == 'Ciência de dados':
            lista_index_dados.append(i)
# Out:
# <ipython-input-58-7ac3db086476>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tecnico['Setor Técnico (função)'][i]=tecnico['Setor Técnico (função)'][i].split(',')

# %%
tecnico.loc[lista_index_prog,:]  # inscritos da area de programação
# Out:
#                        Nome completo     Telefone  \
# 1    Pedro Augusto De Jesus Da Silva  21985319506
# 4             Eldio Luiz Cortez Neto  84998271056
# 11            Phelipe Oliveira Jesus  11964792391
# 13  Fábio Mcgougen Nogueira Correia   17988228819
# 19                   Ranieri Althoff  46760298255
# 20        Vinicius Nascimento Aguiar  19999361919
# 22            Artur Pereira Da Silva  89999023379
#
#                               E-mail         Twitter       Instagram  \
# 1               pedroajs93@gmail.com       pedroajs1  pedroaugustojs
# 4                cortezneto@live.com        safstand    elcortezneto
# 11   phelipe_oliveira_97@hotmail.com  phelipe_oliver             NaN
# 13  fabionogueiracorreia@outlook.com     _gougen_nog      Nog_gougen
# 19                ranisalt@gmail.com        ranisalt        ranisalt
# 20                  vncsna@gmail.com          vncsna          vncsna
# 22               arturapsq@gmail.com       Arturbr97       arturps97
#
# ...

# %%
tecnico.loc[lista_index_dados,:]  # inscritos da area de datascience
# Out:
#                              Nome completo     Telefone  \
# 11                  Phelipe Oliveira Jesus  11964792391
# 13        Fábio Mcgougen Nogueira Correia   17988228819
# 17                      Felipe Ito Anuatti  16993078433
# 19                         Ranieri Althoff  46760298255
# 20              Vinicius Nascimento Aguiar  19999361919
# 22                  Artur Pereira Da Silva  89999023379
# 28                   Gendson Teles Moreira  38992571105
# 33  Estevao Raffaine Vilas Boas De Freitas  11986428118
# 34                 Mateus Santos Rodrigues  11959578440
#
#                               E-mail         Twitter        Instagram  \
# 11   phelipe_oliveira_97@hotmail.com  phelipe_oliver              NaN
# 13  fabionogueiracorreia@outlook.com     _gougen_nog       Nog_gougen
# 17          felito.anuatti@gmail.com     ito_anuatti       itoanuatti
# 19                ranisalt@gmail.com        ranisalt         ranisalt
# ...

# %% [markdown]
# ## REDES SOCIAIS

# %%
#--- este loop abre os perfis do twitter e instagram dos inscritos de acordo com o indice

#for i in dados.Twitter.dropna().index:
webbrowser.open_new_tab('https://twitter.com/'+dados.Twitter[1])
    
#for i in dados.Instagram.dropna().index:
webbrowser.open_new_tab('https://instagram.com/'+dados.Instagram[1])

#---------end----------
# Out:
# True
